# %%
import os
from dotenv import load_dotenv
load_dotenv()

groq_api_key=os.getenv("GROQ_KEY")
groq_api_key
# Out:
# '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'

# %%
from langchain_groq import ChatGroq
model=ChatGroq(model="Gemma2-9b-It",groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001E406A6B400>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001E406AA08B0>, model_name='Gemma2-9b-It', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage,SystemMessage

messages=[
    SystemMessage(content="Translate following from English to French"),
    HumanMessage(content="Helloe how are you?")

]
result=model.invoke(messages)
result
# Out:
# AIMessage(content='The most common way to say "Hello, how are you?" in French is:\n\n**Bonjour, comment allez-vous ?** \n\nHere\'s a breakdown:\n\n* **Bonjour:** Hello\n* **Comment:** How\n* **allez-vous:**  are you (formal, polite)\n\n\nLet me know if you\'d like to know other ways to say it! 😊 \n', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 84, 'prompt_tokens': 21, 'total_tokens': 105, 'completion_time': 0.152727273, 'prompt_time': 0.002181606, 'queue_time': 0.232372805, 'total_time': 0.154908879}, 'model_name': 'Gemma2-9b-It', 'system_fingerprint': 'fp_10c08bf97d', 'finish_reason': 'stop', 'logprobs': None}, id='run-8a957c70-7c02-4b25-b0f6-5a317460801c-0', usage_metadata={'input_tokens': 21, 'output_tokens': 84, 'total_tokens': 105})

# %%
from langchain_core.output_parsers import StrOutputParser
parser=StrOutputParser()
parser.invoke(result)
# Out:
# 'The most common way to say "Hello, how are you?" in French is:\n\n**Bonjour, comment allez-vous ?** \n\nHere\'s a breakdown:\n\n* **Bonjour:** Hello\n* **Comment:** How\n* **allez-vous:**  are you (formal, polite)\n\n\nLet me know if you\'d like to know other ways to say it! 😊 \n'

# %%
#using lcel-chain components
chain=model|parser
chain.invoke(messages)
# Out:
# "Bonjour, comment allez-vous ? \n\n\nLet me know if you have any other phrases you'd like me to translate! \n"

# %%
##prompt tempelate

from langchain_core.prompts import ChatPromptTemplate

generic_template="translate the following into {language}"

prompt=ChatPromptTemplate.from_messages(
    [("system",generic_template),("user","{text}")])
prompt
# Out:
# ChatPromptTemplate(input_variables=['language', 'text'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='translate the following into {language}'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['text'], input_types={}, partial_variables={}, template='{text}'), additional_kwargs={})])

# %%
result=prompt.invoke({"language":"French","text":"hello"})
result
# Out:
# ChatPromptValue(messages=[SystemMessage(content='translate the following into French', additional_kwargs={}, response_metadata={}), HumanMessage(content='hello', additional_kwargs={}, response_metadata={})])

# %%
result.to_messages()
# Out:
# [SystemMessage(content='translate the following into French', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='hello', additional_kwargs={}, response_metadata={})]

# %%
##chaining together compoenet with lcel
chain=prompt|model|parser
chain.invoke({"language":"French","text":"hello"})
# Out:
# 'Bonjour \n'
